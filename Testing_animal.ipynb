# %% [markdown]
# # Testing the pre-trained model
#
# 2018-12-16 Sunday 17:00 HenrySHE
#
# > I have alrady train the model, and the testing accuracy is 95%+, and then this notebook is used to do testing,
# > loading the pre-trained model `structure_weights.h5` and the model called `structure.json`.

# %%
import numpy as np
import cv2 as cv
import scipy.misc
from keras.models import model_from_json
from keras.optimizers import SGD
from glob import glob

# %%
#load model
model_architecture = 'structure.json'
model_weights = 'structure_weights.h5'
model = model_from_json(open(model_architecture).read())
model.load_weights(model_weights)

# %% [markdown]
# # Testing
#
# > input must be 4-dimensions images, and it should be 65*65*3 for each image, and then append them to one array list and devided by 255.
#
# Now it can estimate 3 types of animals
#
# DC --> 0
#
# EAP --> 1
#
# WP --> 2

# %%
#load images
'''
img_names = ['EAP.PNG', 'DC.PNG','WP.PNG']
imgs = [np.transpose(scipy.misc.imresize(scipy.misc.imread(img_name), (32, 32)),
                     (1, 0, 2)).astype('float32')
           for img_name in img_names]
imgs = np.array(imgs) / 255

data = []
img = cv.imread('DC.PNG')
data.append(img)
img2 = cv.imread('WP.PNG')
data.append(img2)
img3 = cv.imread('EAP.PNG')
data.append(img3)
data = np.array(data)/255
print(data.shape)
'''

data = []
#Read all the files in the folder
filenames = []
#filenames = [img for img in glob("Training_Data/EAP/*.jpg")]
filenames = [img for img in glob("/Users/haoyushe/Code(Local)/LongFuShan_Data/vehicle-detection/data/train/WP/*.PNG")]
filenames.sort()
#print(filenames)

for img_name in filenames:
    img = cv.imread(img_name)
    data.append(img)
    
data =np.array(data)/255

# %%
# train
optim = SGD()
model.compile(loss='categorical_crossentropy', optimizer=optim,
	metrics=['accuracy'])
 
predictions = model.predict_classes(data)
print(predictions)
# Out:
# [2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
#  2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
#  2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
#  2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
#  2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 0 2 2 2 2 2 2 2 2 2
#  2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
#  2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2]

# %%
num = 1
count = 0
for i in predictions:
    if i==0:
        print('The '+str(num)+' animal is DC')
        
    if i==1:
        print('The '+str(num)+' animal is EAP')
        
    if i==2:
        print('The '+str(num)+' animal is WP')
        count = count+1
    num=num+1

print('The accuracy is: '+str(count/240)+'%')
# Out:
# The 1 animal is WP
# The 2 animal is WP
# The 3 animal is WP
# The 4 animal is WP
# The 5 animal is WP
# The 6 animal is WP
# The 7 animal is WP
# The 8 animal is WP
# The 9 animal is WP
# The 10 animal is WP
# The 11 animal is WP
# The 12 animal is WP
# The 13 animal is WP
# The 14 animal is WP
# The 15 animal is WP
# The 16 animal is WP
# The 17 animal is WP
# The 18 animal is WP
# The 19 animal is WP
# The 20 animal is WP
# The 21 animal is WP
# The 22 animal is WP
# The 23 animal is WP
# The 24 animal is WP
# The 25 animal is WP
# The 26 animal is WP
# The 27 animal is WP
# The 28 animal is WP
# The 29 animal is WP
# The 30 animal is WP
# The 31 animal is WP
# The 32 animal is WP
# The 33 animal is WP
# The 34 animal is WP
# The 35 animal is WP
# The 36 animal is WP
# The 37 animal is WP
# The 38 animal is WP
# The 39 animal is WP
# The 40 animal is WP
# The 41 animal is WP
# The 42 animal is WP
# The 43 animal is WP
# The 44 animal is WP
# The 45 animal is WP
# ...
